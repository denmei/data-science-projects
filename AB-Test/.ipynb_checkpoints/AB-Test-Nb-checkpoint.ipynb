# %%
# imports
import pandas as pd
import numpy as np
import seaborn as sns

# turn off warnings
import warnings
warnings.filterwarnings('ignore')

# read data
events_df = pd.read_csv("GB_events.csv")
venues_df = pd.read_csv("ldn_venues.csv")
print("# venues: %s" % len(venues_df))
# Out:
# # venues: 982

# %% [markdown]
# # About this Notebook
#
# The following questions should be answered:
#
# **Business-Perspective**:
# * Does the new feature increase the probability that a booking process is completed?
#
# **Regarding the user experience**:
# * Does the new feature help to decrease the search time?
# * Do users find the recommendations useful?

# %% [markdown]
# # Data Exploration

# %%
print("# events: %s" % len(events_df) + "\n")
print(events_df.columns)

# are there multiple bookings/confirmations per session?
conf_df = events_df[(events_df['page_type_category'] == 'Confirmed') & (events_df['event'] == 'page_view')][['page_type_category', 'session_id']] \
    .groupby("session_id", as_index=False) \
    .count() \
    .rename(columns={'page_type_category': 'confirmation_counts'})
print(conf_df.sort_values('confirmation_counts', ascending=False).head(5))
    
conf_df = conf_df.groupby("confirmation_counts", as_index=False).count().rename(columns={'session_id': 'session_counts'})

conf_df.plot.bar(x='confirmation_counts', y='session_counts')
# Out:
# # events: 2968899
#
# Index(['Unnamed: 0', 'X', 'session_id', 'collector_time', 'event',
#        'filtered_top_rated', 'page_type_category', 'venue_id'],
#       dtype='object')
#                              session_id  confirmation_counts
# 1720   178d9bce60af484258b14f17937d85a4                   14
# 5247   45b279428c6ab3c088cc3f65711dd7e5                   14
# 15564  cf41e88ff397313428ebb23e47b16d08                   13
# 3444   2ec8c5ff3ca1a6431c30f4eac2bf75ea                   12
# 10717  8dfb8788ac8ed31b335150c55da1cb50                   12

# %%
print(venues_df.columns)
# Out:
# Index(['Unnamed: 0', 'venue_id', 'purchasable_date', 'churn_date',
#        'top_rated_info'],
#       dtype='object')

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Check missing values

# %%
events_df['filtered_top_rated'] = events_df['filtered_top_rated'] == 'y'
events_cnt = len(events_df)
for column in events_df.columns:
    print(column + ": " + str(len(events_df.dropna(axis=0, subset=[column]))/events_cnt *100) + "%")
print("")

# replace top_rated_info by boolean field
venues_df['top_rated'] = (venues_df['top_rated_info'] == True)
venues_df2 = venues_df.drop('top_rated_info', axis=1)

venues_cnt = len(venues_df2)
for column in venues_df2.columns:
    print(column + ": " + str(len(venues_df2.dropna(axis=0, subset=[column]))/venues_cnt *100) + "%")
# Out:
# Unnamed: 0: 100.0%
# X: 100.0%
# session_id: 100.0%
# collector_time: 100.0%
# event: 100.0%
# filtered_top_rated: 100.0%
# page_type_category: 100.0%
# venue_id: 49.13336560118751%
#
# Unnamed: 0: 100.0%
# venue_id: 100.0%
# purchasable_date: 100.0%
# churn_date: 13.64562118126273%
# top_rated: 100.0%

# %% [markdown]
# ## Create bookingcycle-table
# A new cycle starts with a new session or after a previous booking within the same session and ends when a user reaches the confirmation page or when the session ends.
#
# ### Get bookingcycles
# Booking Table
# - ID: sessionid + starttime
# - Starttime
# - Endtime
# - Successful (ended with confirmation) [bool]
# - ratings available [bool]
# - Time to confirmation in seconds [int]
# - Time to last time-selection in seconds [int] -> search time
# - Number of clicks
# - Venue-ID

# %%
# add some additional columns as preparation for the labeling
session_ids = set(events_df['session_id'])
booking_cycles = pd.DataFrame()
session_starts = events_df.groupby('session_id')['X'].min()
session_ends = events_df.groupby('session_id')['X'].max()

events_df['prev_page_type'] = events_df.groupby('session_id')['page_type_category'].shift(1)
events_df['next_page_type'] = events_df.groupby('session_id')['page_type_category'].shift(-1)


def label_event(category, prev_category, next_category):
    """
    Labels an event as start or end of a booking cycle if applicable.
    """
    if(category == 'Confirmed'):
        return 'confirmation_end'
    elif((prev_category == 'Confirmed') & (category != 'Confirmed')):
        return 'booking_start'
    elif(pd.isna(prev_category)):
        return 'booking_start'
    elif(pd.isna(next_category)):
        return 'booking_end'
    else:
        return ""

# label every event
events_df['label'] = events_df \
    .apply(lambda x: label_event(x['page_type_category'], x['prev_page_type'], x['next_page_type']), axis=1)

# %%
# create booking cycle table
booking_events = events_df[events_df['label'] != ""] 
booking_events[['next_label', 'next_time', 'end_id']] = booking_events.groupby('session_id')[['label', 'collector_time', 'X']].shift(-1)

booking_cycles = booking_events[(booking_events['label'] == 'booking_start') &\
                                ((booking_events['next_label'] == 'booking_end') |\
                                 (booking_events['next_label'] == 'confirmation_end'))]

booking_cycles['start_time'] = pd.to_datetime(booking_cycles['collector_time'])
booking_cycles['end_time'] = pd.to_datetime(booking_cycles['next_time'])
booking_cycles['start_id'] = booking_cycles['X']
booking_cycles['cycle_time_seconds'] = (booking_cycles['end_time'] - booking_cycles['start_time']).dt.total_seconds()
booking_cycles['confirmed'] = booking_cycles['next_label'] == 'confirmation_end'
booking_cycles['cycle_id'] = booking_cycles['session_id'] + str(booking_cycles['start_time'])

# add column that indicates whether the new top rated-feature was available
booking_cycles['feature_available'] = booking_cycles['start_time'] >= "2017-10-04 00:00:00"

# remove redundant columns
booking_cycles = booking_cycles[['cycle_id', 'session_id', 'start_time', 'end_time', 'cycle_time_seconds', \
                                 'confirmed', 'feature_available', 'start_id', 'end_id']]

# %%
# testing the results on a session with multiple bookings
print((booking_cycles[booking_cycles['session_id'] == '72d226e3488091bbcc5381466400dc0b']\
       [['start_time', 'end_time', 'start_id', 'end_id', 'confirmed']]))
print("")
for i, row in (events_df[(events_df['session_id'] == '72d226e3488091bbcc5381466400dc0b')]\
      [['collector_time', 'X', 'page_type_category']]).iterrows():
    print(row[['page_type_category', 'collector_time', 'X']])
# Out:
#                  start_time            end_time  start_id     end_id  \
# 1956215 2017-10-14 15:18:11 2017-10-14 15:29:20   1956216  1956279.0
# 1956280 2017-10-14 15:29:40 2017-10-14 15:35:37   1956281  1956331.0
# 1956331 2017-10-14 15:35:44 2017-10-14 16:24:41   1956332  1956660.0
# 1956661 2017-10-14 16:25:05 2017-10-14 16:45:18   1956662  1956786.0
# 1956787 2017-10-14 16:45:31 2017-10-14 16:57:01   1956788  1956846.0
# 1956847 2017-10-14 16:57:13 2017-10-14 17:02:22   1956848  1956854.0
#
#          confirmed
# 1956215       True
# 1956280       True
# 1956331       True
# 1956661       True
# 1956787       True
# 1956847      False
#
# page_type_category               Homepage
# collector_time        2017-10-14 15:18:11
# X                                 1956216
# Name: 1956215, dtype: object
# page_type_category               Homepage
# collector_time        2017-10-14 15:19:24
# X                                 1956217
# Name: 1956216, dtype: object
# page_type_category               Homepage
# collector_time        2017-10-14 15:19:28
# X                                 1956218
# Name: 1956217, dtype: object
# page_type_category               Homepage
# collector_time        2017-10-14 15:19:34
# X                                 1956219
# Name: 1956218, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:19:38
# X                                 1956220
# Name: 1956219, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:19:52
# X                                 1956221
# Name: 1956220, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:19:53
# X                                 1956222
# Name: 1956221, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:19:54
# X                                 1956223
# Name: 1956222, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:19:54
# X                                 1956224
# Name: 1956223, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:19:55
# X                                 1956225
# Name: 1956224, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:19:58
# X                                 1956226
# Name: 1956225, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:19:58
# X                                 1956227
# Name: 1956226, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:19:59
# X                                 1956228
# Name: 1956227, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:19:59
# X                                 1956229
# Name: 1956228, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:20:00
# X                                 1956230
# Name: 1956229, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:20:01
# X                                 1956231
# Name: 1956230, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:20:04
# X                                 1956232
# Name: 1956231, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:20:04
# X                                 1956233
# Name: 1956232, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:20:10
# X                                 1956234
# Name: 1956233, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:20:13
# X                                 1956235
# Name: 1956234, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:20:40
# X                                 1956236
# Name: 1956235, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:21:40
# X                                 1956237
# Name: 1956236, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:22:03
# X                                 1956238
# Name: 1956237, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:22:23
# X                                 1956239
# Name: 1956238, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:22:23
# X                                 1956240
# Name: 1956239, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:22:24
# X                                 1956241
# Name: 1956240, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:22:37
# X                                 1956242
# Name: 1956241, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:22:37
# X                                 1956243
# Name: 1956242, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:22:39
# X                                 1956244
# Name: 1956243, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:22:42
# X                                 1956245
# Name: 1956244, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:22:50
# X                                 1956246
# Name: 1956245, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:22:50
# X                                 1956247
# Name: 1956246, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:22:52
# X                                 1956248
# Name: 1956247, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:22:53
# X                                 1956249
# Name: 1956248, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:23:11
# X                                 1956250
# Name: 1956249, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:23:11
# X                                 1956251
# Name: 1956250, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:23:30
# X                                 1956252
# Name: 1956251, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:23:47
# X                                 1956253
# Name: 1956252, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:23:51
# X                                 1956254
# Name: 1956253, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:24:03
# X                                 1956255
# Name: 1956254, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:24:05
# X                                 1956256
# Name: 1956255, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:24:07
# X                                 1956257
# Name: 1956256, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:24:13
# X                                 1956258
# Name: 1956257, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:24:14
# X                                 1956259
# Name: 1956258, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:24:54
# X                                 1956260
# Name: 1956259, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:24:55
# X                                 1956261
# Name: 1956260, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:24:57
# X                                 1956262
# Name: 1956261, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:24:59
# X                                 1956263
# Name: 1956262, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:25:07
# X                                 1956264
# Name: 1956263, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:25:09
# X                                 1956265
# Name: 1956264, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:25:10
# X                                 1956266
# Name: 1956265, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:25:43
# X                                 1956267
# Name: 1956266, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:25:44
# X                                 1956268
# Name: 1956267, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:25:52
# X                                 1956269
# Name: 1956268, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:25:59
# X                                 1956270
# Name: 1956269, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:26:08
# X                                 1956271
# Name: 1956270, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:27:23
# X                                 1956272
# Name: 1956271, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:27:23
# X                                 1956273
# Name: 1956272, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:27:26
# X                                 1956274
# Name: 1956273, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:27:29
# X                                 1956275
# Name: 1956274, dtype: object
# page_type_category    Time-selection Page
# collector_time        2017-10-14 15:27:57
# X                                 1956276
# Name: 1956275, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:27:57
# X                                 1956277
# Name: 1956276, dtype: object
# page_type_category               Checkout
# collector_time        2017-10-14 15:28:37
# X                                 1956278
# Name: 1956277, dtype: object
# page_type_category              Confirmed
# collector_time        2017-10-14 15:29:20
# X                                 1956279
# Name: 1956278, dtype: object
# page_type_category              Confirmed
# collector_time        2017-10-14 15:29:20
# X                                 1956280
# Name: 1956279, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:29:40
# X                                 1956281
# Name: 1956280, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:30:03
# X                                 1956282
# Name: 1956281, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:30:03
# X                                 1956283
# Name: 1956282, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:30:46
# X                                 1956284
# Name: 1956283, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:30:48
# X                                 1956285
# Name: 1956284, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:30:49
# X                                 1956286
# Name: 1956285, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:30:51
# X                                 1956287
# Name: 1956286, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:31:02
# X                                 1956288
# Name: 1956287, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:31:22
# X                                 1956289
# Name: 1956288, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:31:22
# X                                 1956290
# Name: 1956289, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:31:36
# X                                 1956291
# Name: 1956290, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:31:37
# X                                 1956292
# Name: 1956291, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:31:38
# X                                 1956293
# Name: 1956292, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:31:39
# X                                 1956294
# Name: 1956293, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:31:41
# X                                 1956295
# Name: 1956294, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:31:42
# X                                 1956296
# Name: 1956295, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:31:43
# X                                 1956297
# Name: 1956296, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:31:45
# X                                 1956298
# Name: 1956297, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:31:51
# X                                 1956299
# Name: 1956298, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:31:53
# X                                 1956300
# Name: 1956299, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:32:01
# X                                 1956301
# Name: 1956300, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:32:04
# X                                 1956302
# Name: 1956301, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:32:06
# X                                 1956303
# Name: 1956302, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:32:28
# X                                 1956304
# Name: 1956303, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:32:28
# X                                 1956305
# Name: 1956304, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:32:30
# X                                 1956306
# Name: 1956305, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:32:30
# X                                 1956307
# Name: 1956306, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:32:31
# X                                 1956308
# Name: 1956307, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:32:37
# X                                 1956309
# Name: 1956308, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:33:06
# X                                 1956310
# Name: 1956309, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:33:06
# X                                 1956311
# Name: 1956310, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:33:06
# X                                 1956312
# Name: 1956311, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:33:07
# X                                 1956313
# Name: 1956312, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:33:43
# X                                 1956314
# Name: 1956313, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:33:43
# X                                 1956315
# Name: 1956314, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:33:43
# X                                 1956316
# Name: 1956315, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:33:43
# X                                 1956317
# Name: 1956316, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:33:59
# X                                 1956318
# Name: 1956317, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:34:00
# X                                 1956319
# Name: 1956318, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:34:18
# X                                 1956320
# Name: 1956319, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:34:57
# X                                 1956321
# Name: 1956320, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:34:57
# X                                 1956322
# Name: 1956321, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:34:57
# X                                 1956323
# Name: 1956322, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:34:57
# X                                 1956324
# Name: 1956323, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:35:14
# X                                 1956325
# Name: 1956324, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:35:15
# X                                 1956326
# Name: 1956325, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:35:17
# X                                 1956327
# Name: 1956326, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:35:17
# X                                 1956328
# Name: 1956327, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:35:18
# X                                 1956329
# Name: 1956328, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:35:34
# X                                 1956330
# Name: 1956329, dtype: object
# page_type_category              Confirmed
# collector_time        2017-10-14 15:35:37
# X                                 1956331
# Name: 1956330, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:35:44
# X                                 1956332
# Name: 1956331, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:35:57
# X                                 1956333
# Name: 1956332, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:35:57
# X                                 1956334
# Name: 1956333, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:36:06
# X                                 1956335
# Name: 1956334, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:36:13
# X                                 1956336
# Name: 1956335, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:36:28
# X                                 1956337
# Name: 1956336, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:36:56
# X                                 1956338
# Name: 1956337, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:36:56
# X                                 1956339
# Name: 1956338, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:37:07
# X                                 1956340
# Name: 1956339, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:37:07
# X                                 1956341
# Name: 1956340, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:37:15
# X                                 1956342
# Name: 1956341, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:38:06
# X                                 1956343
# Name: 1956342, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:38:49
# X                                 1956344
# Name: 1956343, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:39:49
# X                                 1956345
# Name: 1956344, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:39:52
# X                                 1956346
# Name: 1956345, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:39:54
# X                                 1956347
# Name: 1956346, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:39:55
# X                                 1956348
# Name: 1956347, dtype: object
# page_type_category    Time-selection Page
# collector_time        2017-10-14 15:40:08
# X                                 1956349
# Name: 1956348, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:40:08
# X                                 1956350
# Name: 1956349, dtype: object
# page_type_category               Checkout
# collector_time        2017-10-14 15:40:40
# X                                 1956351
# Name: 1956350, dtype: object
# page_type_category    Time-selection Page
# collector_time        2017-10-14 15:41:52
# X                                 1956352
# Name: 1956351, dtype: object
# page_type_category    Time-selection Page
# collector_time        2017-10-14 15:41:58
# X                                 1956353
# Name: 1956352, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:42:14
# X                                 1956354
# Name: 1956353, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:42:14
# X                                 1956355
# Name: 1956354, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:42:25
# X                                 1956356
# Name: 1956355, dtype: object
# page_type_category    Time-selection Page
# collector_time        2017-10-14 15:42:26
# X                                 1956357
# Name: 1956356, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:42:44
# X                                 1956358
# Name: 1956357, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:42:44
# X                                 1956359
# Name: 1956358, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:42:47
# X                                 1956360
# Name: 1956359, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:42:49
# X                                 1956361
# Name: 1956360, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:42:57
# X                                 1956362
# Name: 1956361, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:42:58
# X                                 1956363
# Name: 1956362, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:42:59
# X                                 1956364
# Name: 1956363, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:43:00
# X                                 1956365
# Name: 1956364, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:43:03
# X                                 1956366
# Name: 1956365, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:43:03
# X                                 1956367
# Name: 1956366, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:43:07
# X                                 1956368
# Name: 1956367, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:43:31
# X                                 1956369
# Name: 1956368, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:43:38
# X                                 1956370
# Name: 1956369, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:44:00
# X                                 1956371
# Name: 1956370, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:44:00
# X                                 1956372
# Name: 1956371, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:44:09
# X                                 1956373
# Name: 1956372, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:44:09
# X                                 1956374
# Name: 1956373, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:44:16
# X                                 1956375
# Name: 1956374, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:44:16
# X                                 1956376
# Name: 1956375, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:44:16
# X                                 1956377
# Name: 1956376, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:44:17
# X                                 1956378
# Name: 1956377, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:44:27
# X                                 1956379
# Name: 1956378, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:45:00
# X                                 1956380
# Name: 1956379, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:45:00
# X                                 1956381
# Name: 1956380, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:45:13
# X                                 1956382
# Name: 1956381, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:45:14
# X                                 1956383
# Name: 1956382, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:45:16
# X                                 1956384
# Name: 1956383, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:45:16
# X                                 1956385
# Name: 1956384, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:45:17
# X                                 1956386
# Name: 1956385, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:45:17
# X                                 1956387
# Name: 1956386, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:45:17
# X                                 1956388
# Name: 1956387, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:45:18
# X                                 1956389
# Name: 1956388, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:45:22
# X                                 1956390
# Name: 1956389, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:45:25
# X                                 1956391
# Name: 1956390, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:45:30
# X                                 1956392
# Name: 1956391, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:45:30
# X                                 1956393
# Name: 1956392, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:45:32
# X                                 1956394
# Name: 1956393, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:45:42
# X                                 1956395
# Name: 1956394, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:45:43
# X                                 1956396
# Name: 1956395, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:45:56
# X                                 1956397
# Name: 1956396, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:45:56
# X                                 1956398
# Name: 1956397, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:46:36
# X                                 1956399
# Name: 1956398, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:46:41
# X                                 1956400
# Name: 1956399, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:46:49
# X                                 1956401
# Name: 1956400, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:46:53
# X                                 1956402
# Name: 1956401, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:46:55
# X                                 1956403
# Name: 1956402, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:46:55
# X                                 1956404
# Name: 1956403, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:46:57
# X                                 1956405
# Name: 1956404, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:47:50
# X                                 1956406
# Name: 1956405, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:48:03
# X                                 1956407
# Name: 1956406, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:48:03
# X                                 1956408
# Name: 1956407, dtype: object
# page_type_category    Time-selection Page
# collector_time        2017-10-14 15:48:07
# X                                 1956409
# Name: 1956408, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:48:07
# X                                 1956410
# Name: 1956409, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:48:18
# X                                 1956411
# Name: 1956410, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:48:18
# X                                 1956412
# Name: 1956411, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:48:20
# X                                 1956413
# Name: 1956412, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:48:20
# X                                 1956414
# Name: 1956413, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:48:24
# X                                 1956415
# Name: 1956414, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:48:36
# X                                 1956416
# Name: 1956415, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:48:36
# X                                 1956417
# Name: 1956416, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:48:59
# X                                 1956418
# Name: 1956417, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:48:59
# X                                 1956419
# Name: 1956418, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:49:11
# X                                 1956420
# Name: 1956419, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:49:12
# X                                 1956421
# Name: 1956420, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:49:14
# X                                 1956422
# Name: 1956421, dtype: object
# page_type_category    Time-selection Page
# collector_time        2017-10-14 15:49:15
# X                                 1956423
# Name: 1956422, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:49:30
# X                                 1956424
# Name: 1956423, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:49:30
# X                                 1956425
# Name: 1956424, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:49:32
# X                                 1956426
# Name: 1956425, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:49:44
# X                                 1956427
# Name: 1956426, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:50:05
# X                                 1956428
# Name: 1956427, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:50:05
# X                                 1956429
# Name: 1956428, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:50:24
# X                                 1956430
# Name: 1956429, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:50:26
# X                                 1956431
# Name: 1956430, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:50:35
# X                                 1956432
# Name: 1956431, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:50:36
# X                                 1956433
# Name: 1956432, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:50:47
# X                                 1956434
# Name: 1956433, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:51:05
# X                                 1956435
# Name: 1956434, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:51:12
# X                                 1956436
# Name: 1956435, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:51:25
# X                                 1956437
# Name: 1956436, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:51:25
# X                                 1956438
# Name: 1956437, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:51:26
# X                                 1956439
# Name: 1956438, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:51:27
# X                                 1956440
# Name: 1956439, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:51:35
# X                                 1956441
# Name: 1956440, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:51:43
# X                                 1956442
# Name: 1956441, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:51:43
# X                                 1956443
# Name: 1956442, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:51:44
# X                                 1956444
# Name: 1956443, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:51:54
# X                                 1956445
# Name: 1956444, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:52:11
# X                                 1956446
# Name: 1956445, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:52:11
# X                                 1956447
# Name: 1956446, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:52:21
# X                                 1956448
# Name: 1956447, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:52:21
# X                                 1956449
# Name: 1956448, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:52:25
# X                                 1956450
# Name: 1956449, dtype: object
# page_type_category    Time-selection Page
# collector_time        2017-10-14 15:52:32
# X                                 1956451
# Name: 1956450, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:52:32
# X                                 1956452
# Name: 1956451, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:52:43
# X                                 1956453
# Name: 1956452, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:52:43
# X                                 1956454
# Name: 1956453, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:52:44
# X                                 1956455
# Name: 1956454, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:53:07
# X                                 1956456
# Name: 1956455, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:53:07
# X                                 1956457
# Name: 1956456, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:53:08
# X                                 1956458
# Name: 1956457, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:53:12
# X                                 1956459
# Name: 1956458, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:53:12
# X                                 1956460
# Name: 1956459, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:53:23
# X                                 1956461
# Name: 1956460, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:53:26
# X                                 1956462
# Name: 1956461, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:53:37
# X                                 1956463
# Name: 1956462, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:53:39
# X                                 1956464
# Name: 1956463, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:53:48
# X                                 1956465
# Name: 1956464, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:53:54
# X                                 1956466
# Name: 1956465, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:53:54
# X                                 1956467
# Name: 1956466, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:53:55
# X                                 1956468
# Name: 1956467, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:54:11
# X                                 1956469
# Name: 1956468, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:54:30
# X                                 1956470
# Name: 1956469, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:54:30
# X                                 1956471
# Name: 1956470, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:54:33
# X                                 1956472
# Name: 1956471, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:54:33
# X                                 1956473
# Name: 1956472, dtype: object
# page_type_category    Time-selection Page
# collector_time        2017-10-14 15:54:35
# X                                 1956474
# Name: 1956473, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:54:35
# X                                 1956475
# Name: 1956474, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:55:33
# X                                 1956476
# Name: 1956475, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 15:55:33
# X                                 1956477
# Name: 1956476, dtype: object
# page_type_category               Homepage
# collector_time        2017-10-14 15:55:38
# X                                 1956478
# Name: 1956477, dtype: object
# page_type_category               Homepage
# collector_time        2017-10-14 15:55:38
# X                                 1956479
# Name: 1956478, dtype: object
# page_type_category               Homepage
# collector_time        2017-10-14 15:55:47
# X                                 1956480
# Name: 1956479, dtype: object
# page_type_category               Homepage
# collector_time        2017-10-14 15:55:49
# X                                 1956481
# Name: 1956480, dtype: object
# page_type_category               Homepage
# collector_time        2017-10-14 15:55:54
# X                                 1956482
# Name: 1956481, dtype: object
# page_type_category               Homepage
# collector_time        2017-10-14 15:56:01
# X                                 1956483
# Name: 1956482, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:56:02
# X                                 1956484
# Name: 1956483, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 15:56:12
# X                                 1956485
# Name: 1956484, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:00:41
# X                                 1956486
# Name: 1956485, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:00:41
# X                                 1956487
# Name: 1956486, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 16:01:07
# X                                 1956488
# Name: 1956487, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 16:01:08
# X                                 1956489
# Name: 1956488, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 16:01:08
# X                                 1956490
# Name: 1956489, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 16:01:08
# X                                 1956491
# Name: 1956490, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 16:01:09
# X                                 1956492
# Name: 1956491, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 16:01:09
# X                                 1956493
# Name: 1956492, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 16:01:10
# X                                 1956494
# Name: 1956493, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 16:01:38
# X                                 1956495
# Name: 1956494, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 16:02:27
# X                                 1956496
# Name: 1956495, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:02:51
# X                                 1956497
# Name: 1956496, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:02:51
# X                                 1956498
# Name: 1956497, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:03:17
# X                                 1956499
# Name: 1956498, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:03:17
# X                                 1956500
# Name: 1956499, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:03:30
# X                                 1956501
# Name: 1956500, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:03:30
# X                                 1956502
# Name: 1956501, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:03:43
# X                                 1956503
# Name: 1956502, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:03:45
# X                                 1956504
# Name: 1956503, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:03:46
# X                                 1956505
# Name: 1956504, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:03:58
# X                                 1956506
# Name: 1956505, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:04:09
# X                                 1956507
# Name: 1956506, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:04:09
# X                                 1956508
# Name: 1956507, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:04:10
# X                                 1956509
# Name: 1956508, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:04:11
# X                                 1956510
# Name: 1956509, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:04:16
# X                                 1956511
# Name: 1956510, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:04:16
# X                                 1956512
# Name: 1956511, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:04:38
# X                                 1956513
# Name: 1956512, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:04:46
# X                                 1956514
# Name: 1956513, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:04:47
# X                                 1956515
# Name: 1956514, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:04:49
# X                                 1956516
# Name: 1956515, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:04:52
# X                                 1956517
# Name: 1956516, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:04:56
# X                                 1956518
# Name: 1956517, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:04:56
# X                                 1956519
# Name: 1956518, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:04:57
# X                                 1956520
# Name: 1956519, dtype: object
# page_type_category             Venue Page
# ...
# Name: 1956750, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:36:53
# X                                 1956752
# Name: 1956751, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:36:58
# X                                 1956753
# Name: 1956752, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:37:02
# X                                 1956754
# Name: 1956753, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:37:28
# X                                 1956755
# Name: 1956754, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:37:30
# X                                 1956756
# Name: 1956755, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:37:31
# X                                 1956757
# Name: 1956756, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:37:33
# X                                 1956758
# Name: 1956757, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:37:44
# X                                 1956759
# Name: 1956758, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:37:52
# X                                 1956760
# Name: 1956759, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:37:55
# X                                 1956761
# Name: 1956760, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:38:32
# X                                 1956762
# Name: 1956761, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:38:34
# X                                 1956763
# Name: 1956762, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:39:01
# X                                 1956764
# Name: 1956763, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:39:12
# X                                 1956765
# Name: 1956764, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:39:14
# X                                 1956766
# Name: 1956765, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:39:16
# X                                 1956767
# Name: 1956766, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:39:29
# X                                 1956768
# Name: 1956767, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:40:38
# X                                 1956769
# Name: 1956768, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:40:40
# X                                 1956770
# Name: 1956769, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:42:29
# X                                 1956771
# Name: 1956770, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:42:29
# X                                 1956772
# Name: 1956771, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:42:33
# X                                 1956773
# Name: 1956772, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:42:36
# X                                 1956774
# Name: 1956773, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:42:51
# X                                 1956775
# Name: 1956774, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:42:54
# X                                 1956776
# Name: 1956775, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:42:55
# X                                 1956777
# Name: 1956776, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:43:22
# X                                 1956778
# Name: 1956777, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:43:23
# X                                 1956779
# Name: 1956778, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:43:24
# X                                 1956780
# Name: 1956779, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:43:24
# X                                 1956781
# Name: 1956780, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:43:26
# X                                 1956782
# Name: 1956781, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:43:30
# X                                 1956783
# Name: 1956782, dtype: object
# page_type_category    Time-selection Page
# collector_time        2017-10-14 16:43:31
# X                                 1956784
# Name: 1956783, dtype: object
# page_type_category               Checkout
# collector_time        2017-10-14 16:44:45
# X                                 1956785
# Name: 1956784, dtype: object
# page_type_category              Confirmed
# collector_time        2017-10-14 16:45:18
# X                                 1956786
# Name: 1956785, dtype: object
# page_type_category              Confirmed
# collector_time        2017-10-14 16:45:18
# X                                 1956787
# Name: 1956786, dtype: object
# page_type_category               Homepage
# collector_time        2017-10-14 16:45:31
# X                                 1956788
# Name: 1956787, dtype: object
# page_type_category               Homepage
# collector_time        2017-10-14 16:45:31
# X                                 1956789
# Name: 1956788, dtype: object
# page_type_category               Homepage
# collector_time        2017-10-14 16:45:35
# X                                 1956790
# Name: 1956789, dtype: object
# page_type_category               Homepage
# collector_time        2017-10-14 16:45:38
# X                                 1956791
# Name: 1956790, dtype: object
# page_type_category               Homepage
# collector_time        2017-10-14 16:45:42
# X                                 1956792
# Name: 1956791, dtype: object
# page_type_category               Homepage
# collector_time        2017-10-14 16:45:43
# X                                 1956793
# Name: 1956792, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 16:45:45
# X                                 1956794
# Name: 1956793, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 16:46:16
# X                                 1956795
# Name: 1956794, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:46:24
# X                                 1956796
# Name: 1956795, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:46:24
# X                                 1956797
# Name: 1956796, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:46:34
# X                                 1956798
# Name: 1956797, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:46:36
# X                                 1956799
# Name: 1956798, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:46:38
# X                                 1956800
# Name: 1956799, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:47:00
# X                                 1956801
# Name: 1956800, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:47:24
# X                                 1956802
# Name: 1956801, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:47:30
# X                                 1956803
# Name: 1956802, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:47:30
# X                                 1956804
# Name: 1956803, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:47:41
# X                                 1956805
# Name: 1956804, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:47:41
# X                                 1956806
# Name: 1956805, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:48:20
# X                                 1956807
# Name: 1956806, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:48:20
# X                                 1956808
# Name: 1956807, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:48:21
# X                                 1956809
# Name: 1956808, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:48:37
# X                                 1956810
# Name: 1956809, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:48:40
# X                                 1956811
# Name: 1956810, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:48:57
# X                                 1956812
# Name: 1956811, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:49:14
# X                                 1956813
# Name: 1956812, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:50:11
# X                                 1956814
# Name: 1956813, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:50:11
# X                                 1956815
# Name: 1956814, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:50:13
# X                                 1956816
# Name: 1956815, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:50:20
# X                                 1956817
# Name: 1956816, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:50:22
# X                                 1956818
# Name: 1956817, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:50:22
# X                                 1956819
# Name: 1956818, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:50:23
# X                                 1956820
# Name: 1956819, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:50:39
# X                                 1956821
# Name: 1956820, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:50:39
# X                                 1956822
# Name: 1956821, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:50:44
# X                                 1956823
# Name: 1956822, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:50:51
# X                                 1956824
# Name: 1956823, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:50:51
# X                                 1956825
# Name: 1956824, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:50:52
# X                                 1956826
# Name: 1956825, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:51:16
# X                                 1956827
# Name: 1956826, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:51:27
# X                                 1956828
# Name: 1956827, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:51:27
# X                                 1956829
# Name: 1956828, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:51:30
# X                                 1956830
# Name: 1956829, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:52:33
# X                                 1956831
# Name: 1956830, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:53:06
# X                                 1956832
# Name: 1956831, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:53:15
# X                                 1956833
# Name: 1956832, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:54:24
# X                                 1956834
# Name: 1956833, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:54:24
# X                                 1956835
# Name: 1956834, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:54:25
# X                                 1956836
# Name: 1956835, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:54:47
# X                                 1956837
# Name: 1956836, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:54:47
# X                                 1956838
# Name: 1956837, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:54:52
# X                                 1956839
# Name: 1956838, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:54:54
# X                                 1956840
# Name: 1956839, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:54:56
# X                                 1956841
# Name: 1956840, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:55:01
# X                                 1956842
# Name: 1956841, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:55:09
# X                                 1956843
# Name: 1956842, dtype: object
# page_type_category    Time-selection Page
# collector_time        2017-10-14 16:55:10
# X                                 1956844
# Name: 1956843, dtype: object
# page_type_category               Checkout
# collector_time        2017-10-14 16:56:25
# X                                 1956845
# Name: 1956844, dtype: object
# page_type_category              Confirmed
# collector_time        2017-10-14 16:57:01
# X                                 1956846
# Name: 1956845, dtype: object
# page_type_category              Confirmed
# collector_time        2017-10-14 16:57:01
# X                                 1956847
# Name: 1956846, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:57:13
# X                                 1956848
# Name: 1956847, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 16:57:13
# X                                 1956849
# Name: 1956848, dtype: object
# page_type_category            Browse Page
# collector_time        2017-10-14 17:01:57
# X                                 1956850
# Name: 1956849, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 17:02:10
# X                                 1956851
# Name: 1956850, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 17:02:10
# X                                 1956852
# Name: 1956851, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 17:02:16
# X                                 1956853
# Name: 1956852, dtype: object
# page_type_category             Venue Page
# collector_time        2017-10-14 17:02:22
# X                                 1956854
# Name: 1956853, dtype: object

# %% [markdown]
# ### Additional features:
# * last_venue_viewed: Which venue did the user choose if he placed an order?
# * venue_top_rated: Was the venue among the higher ranked venues?
# * search_time
# * Filtered_top_rating:

# %%
# for every booking that ended with a confirmation, get the latest time-selection event
time_selection_df = events_df[events_df['page_type_category'] == 'Time-selection Page']\
    [['X', 'page_type_category', 'session_id', 'venue_id', 'collector_time']]
bookings_with_times = booking_cycles.merge(time_selection_df, on='session_id', how='left')
bookings_with_times = bookings_with_times[(bookings_with_times['end_id'] >= bookings_with_times['X']) &\
                                        (bookings_with_times['start_id'] <= bookings_with_times['X'])]

bookings_with_times = bookings_with_times.groupby(['cycle_id', 'session_id', 'start_time', 'end_time', \
                                                   'cycle_time_seconds', 'confirmed', 'feature_available', \
                                                   'start_id', 'end_id'], as_index=False).max() 

# extract venue id of the latest venue viewed
bookings_with_venues = bookings_with_times.merge(time_selection_df, on='X', how='left')\
                        [['cycle_id', 'session_id_x', 'start_time', 'end_time', \
                        'cycle_time_seconds', 'confirmed', 'feature_available', \
                        'start_id', 'end_id', 'venue_id_y', 'collector_time_y']] \
                        .rename(columns={'venue_id_y': 'venue_id', 'session_id_x': 'session_id', \
                                         'collector_time_y': 'time_selector_time'})

# add column that shows whether the viewed venue is top rated
bookings_with_venues = bookings_with_venues.merge(venues_df[['venue_id', 'top_rated']], on='venue_id', how='left')\
    .rename(columns={'venue_id': 'last_venue_viewed', 'top_rated': 'venue_top_rated'})

# add search time column (= time between start and last time selection)
bookings_with_venues['time_selector_time'] = pd.to_datetime(bookings_with_venues['time_selector_time'])
bookings_with_venues['search_time'] = (bookings_with_venues['time_selector_time'] - bookings_with_venues['start_time'])\
    .dt.total_seconds()

# %%
# add column that shows whether the user used the top-rated filter
top_rated_events = events_df[events_df['filtered_top_rated'] == True][['session_id', 'X']]
bookings_with_top_rated = bookings_with_venues.merge(top_rated_events, on='session_id', how='left')
bookings_with_top_rated = bookings_with_top_rated[(bookings_with_top_rated['end_id'] >= bookings_with_top_rated['X']) &\
                                        (bookings_with_top_rated['start_id'] <= bookings_with_top_rated['X'])]

cols = list(bookings_with_venues.columns)
bookings_with_top_rated = bookings_with_top_rated.groupby(cols, as_index=False).count()
bookings_with_top_rated['filtered_top_ratings'] = bookings_with_top_rated['X'] > 1
new_cols = cols + ['filtered_top_ratings']
bookings_with_top_rated = bookings_with_top_rated[new_cols]

# test: filter use may only occure after release
assert(bookings_with_top_rated[bookings_with_top_rated['filtered_top_ratings'] == True]\
       ['start_time'].min() > pd.to_datetime('2017-10-04 00:00:00'))

# %% [markdown]
# # Modeling

# %% [markdown]
# # Hypothesis Testing
